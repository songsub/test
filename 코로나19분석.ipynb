# %%
import pandas as pd

# %%
kto_201901 = pd.read_excel('./files/kto_201009.xlsx'  # excel       파일 불러오기
                           ,header = 1                # header      1번으로 사용 
                           ,usecols = 'A:G'           # usecols     A부터 G까지 사용 
                           ,skipfooter=4)             # skipfooter  아래 4개 skip
kto_201901
# Out:
#          국적      관광     상용   공용  유학/연수      기타       계
# 0      아시아주  450210  17665  755  13537  114180  596347
# 1        일본  259846   1791  147    576    5526  267886
# 2        대만   31511     43    5    105     620   32284
# 3        홍콩   13404     39    0     22     841   14306
# 4       마카오     385      1    0      3       2     391
# ..      ...     ...    ...  ...    ...     ...     ...
# 62  아프리카 기타     988    567   57     91     380    2083
# 63     기타대륙      10      3    0      0       1      14
# 64     국적미상      10      3    0      0       1      14
# 65     교포소계       0      0    0      0   26715   26715
# 66       교포       0      0    0      0   26715   26715
#
# [67 rows x 7 columns]

# %%
kto_201901.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   국적      67 non-null     object
#  1   관광      67 non-null     int64
#  2   상용      67 non-null     int64
#  3   공용      67 non-null     int64
#  4   유학/연수   67 non-null     int64
#  5   기타      67 non-null     int64
#  6   계       67 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 3.8+ KB

# %%
kto_201901.describe()
# Out:
#                   관광            상용           공용         유학/연수             기타  \
# count      67.000000     67.000000    67.000000     67.000000      67.000000
# mean    16320.567164    667.223881    67.462687    426.089552    5345.313433
# std     63762.176340   2465.743503   238.474402   2137.075010   16351.137177
# min         0.000000      0.000000     0.000000      0.000000       1.000000
# 25%       385.500000     22.000000     0.000000      4.500000     188.500000
# 50%       837.000000     54.000000     3.000000     20.000000     620.000000
# 75%      5763.500000    349.500000    19.500000     65.000000    1982.000000
# max    450210.000000  17665.000000  1304.000000  13537.000000  114180.000000
#
#                    계
# count      67.000000
# mean    22826.656716
# std     81596.891059
# min        14.000000
# 25%       770.000000
# 50%      1909.000000
# 75%      9583.000000
# max    596347.000000

# %% [markdown]
# - 코로나19 이후 관광목적으로 가장 많이 외국인이 입국
# - 관광 > 기타 > 상용 > 유학/연수 / 공용 순으로 입국

# %%
# 기준연월 추가 => 컬럼 추가 및 2019-1 문구 추가 
kto_201901['기준년월'] = '2019-01'
kto_201901
# Out:
#          국적      관광     상용   공용  유학/연수      기타       계     기준년월
# 0      아시아주  450210  17665  755  13537  114180  596347  2019-01
# 1        일본  259846   1791  147    576    5526  267886  2019-01
# 2        대만   31511     43    5    105     620   32284  2019-01
# 3        홍콩   13404     39    0     22     841   14306  2019-01
# 4       마카오     385      1    0      3       2     391  2019-01
# ..      ...     ...    ...  ...    ...     ...     ...      ...
# 62  아프리카 기타     988    567   57     91     380    2083  2019-01
# 63     기타대륙      10      3    0      0       1      14  2019-01
# 64     국적미상      10      3    0      0       1      14  2019-01
# 65     교포소계       0      0    0      0   26715   26715  2019-01
# 66       교포       0      0    0      0   26715   26715  2019-01
#
# [67 rows x 8 columns]

# %%
kto_201901['국적'].unique()
# Out:
# array(['아시아주', '일본', '대만', '홍콩', '마카오', '태국', '말레이시아', '필리핀', '인도네시아',
#        '싱가포르', '미얀마', '베트남', '인도', '스리랑카', '파키스탄', '방글라데시', '캄보디아', '몽골',
#        '중국', '이란', '이스라엘', '터키', '우즈베키스탄', '카자흐스탄', 'GCC', '아시아 기타', '미주',
#        '미국', '캐나다', '멕시코', '브라질', '미주 기타', '구주', '영국', '독일', '프랑스',
#        '네덜란드', '스웨덴', '스위스', '이탈리아', '덴마크', '노르웨이', '벨기에', '오스트리아', '스페인',
#        '그리스', '포르투갈', '핀란드', '아일랜드', '우크라이나', '러시아', '크로아티아', '루마니아',
#        '불가리아', '폴란드', '구주 기타', '대양주', '오스트레일리아', '뉴질랜드', '대양주 기타',
#        '아프리카주', '남아프리카공화국', '아프리카 기타', '기타대륙', '국적미상', '교포소계', '교포'],
#       dtype=object)

# %%
contents_list = ['아시아주', '미주', '구주', '대양주', '아프리카주', ' 기타대륙', '교포소계']
contents_list
# Out:
# ['아시아주', '미주', '구주', '대양주', '아프리카주', ' 기타대륙', '교포소계']

# %%
# contents_list의 목록에 있는거 제거 
condition = (kto_201901.국적.isin(contents_list) == False)
condition
kto_20190_country = kto_201901[condition]
kto_20190_country['국적'].unique
# Out:
# <bound method Series.unique of 1           일본
# 2           대만
# 3           홍콩
# 4          마카오
# 5           태국
#         ...
# 61    남아프리카공화국
# 62     아프리카 기타
# 63        기타대륙
# 64        국적미상
# 66          교포
# Name: 국적, Length: 61, dtype: object>

# %%
kto_201901_country_newindex = kto_20190_country.reset_index(drop= True)

# %%
kto_201901_country_newindex
# Out:
#           국적      관광    상용   공용  유학/연수     기타       계     기준년월
# 0         일본  259846  1791  147    576   5526  267886  2019-01
# 1         대만   31511    43    5    105    620   32284  2019-01
# 2         홍콩   13404    39    0     22    841   14306  2019-01
# 3        마카오     385     1    0      3      2     391  2019-01
# 4         태국   11562    50   39     50   4524   16225  2019-01
# ..       ...     ...   ...  ...    ...    ...     ...      ...
# 56  남아프리카공화국     407    24    4      7    459     901  2019-01
# 57   아프리카 기타     988   567   57     91    380    2083  2019-01
# 58      기타대륙      10     3    0      0      1      14  2019-01
# 59      국적미상      10     3    0      0      1      14  2019-01
# 60        교포       0     0    0      0  26715   26715  2019-01
#
# [61 rows x 8 columns]

# %% [markdown]
# ### 대륙 colum 추가 및 내용 추가

# %%
continents = ['아시아']*26 + ['아메리카']*5 + ['유럽']*23 + ['오세아니아']*3 + ['아프리카']*2 + ['기타대륙'] + ['교포']
print('{} : sample 데이터 5개 \n {} : type \n {} : len '.format(continents[:5],type(continents),len(continents)))
kto_201901_country_newindex.shape
# Out:
# ['아시아', '아시아', '아시아', '아시아', '아시아'] : sample 데이터 5개
#  <class 'list'> : type
#  61 : len
# (61, 8)

# %%
kto_201901_country_newindex['대륙'] = continents
kto_201901_country_newindex
# Out:
#           국적      관광    상용   공용  유학/연수     기타       계     기준년월     대륙
# 0         일본  259846  1791  147    576   5526  267886  2019-01    아시아
# 1         대만   31511    43    5    105    620   32284  2019-01    아시아
# 2         홍콩   13404    39    0     22    841   14306  2019-01    아시아
# 3        마카오     385     1    0      3      2     391  2019-01    아시아
# 4         태국   11562    50   39     50   4524   16225  2019-01    아시아
# ..       ...     ...   ...  ...    ...    ...     ...      ...    ...
# 56  남아프리카공화국     407    24    4      7    459     901  2019-01  오세아니아
# 57   아프리카 기타     988   567   57     91    380    2083  2019-01   아프리카
# 58      기타대륙      10     3    0      0      1      14  2019-01   아프리카
# 59      국적미상      10     3    0      0      1      14  2019-01   기타대륙
# 60        교포       0     0    0      0  26715   26715  2019-01     교포
#
# [61 rows x 9 columns]

# %%
# 관광비율 살펴보기
kto_201901_country_newindex['관광비율(%)'] = round(kto_201901_country_newindex['관광'] / kto_201901_country_newindex['계'] * 100 , 1)
kto_201901_country_newindex
# Out:
#           국적      관광    상용   공용  유학/연수     기타       계     기준년월     대륙  관광비율(%)
# 0         일본  259846  1791  147    576   5526  267886  2019-01    아시아     97.0
# 1         대만   31511    43    5    105    620   32284  2019-01    아시아     97.6
# 2         홍콩   13404    39    0     22    841   14306  2019-01    아시아     93.7
# 3        마카오     385     1    0      3      2     391  2019-01    아시아     98.5
# 4         태국   11562    50   39     50   4524   16225  2019-01    아시아     71.3
# ..       ...     ...   ...  ...    ...    ...     ...      ...    ...      ...
# 56  남아프리카공화국     407    24    4      7    459     901  2019-01  오세아니아     45.2
# 57   아프리카 기타     988   567   57     91    380    2083  2019-01   아프리카     47.4
# 58      기타대륙      10     3    0      0      1      14  2019-01   아프리카     71.4
# 59      국적미상      10     3    0      0      1      14  2019-01   기타대륙     71.4
# 60        교포       0     0    0      0  26715   26715  2019-01     교포      0.0
#
# [61 rows x 10 columns]

# %%
# 내림차순으로 관광 비율 정렬
# 상위 5개국 
kto_201901_country_newindex.sort_values(by = '관광비율(%)', ascending=False ).head()
# Out:
#       국적      관광    상용   공용  유학/연수    기타       계     기준년월   대륙  관광비율(%)
# 3    마카오     385     1    0      3     2     391  2019-01  아시아     98.5
# 1     대만   31511    43    5    105   620   32284  2019-01  아시아     97.6
# 0     일본  259846  1791  147    576  5526  267886  2019-01  아시아     97.0
# 19  이스라엘     837    10    0      4    40     891  2019-01  아시아     93.9
# 2     홍콩   13404    39    0     22   841   14306  2019-01  아시아     93.7

# %%
# 하위 5개국 
kto_201901_country_newindex.sort_values(by = '관광비율(%)', ascending=False ).tail()
# Out:
#        국적   관광  상용  공용  유학/연수     기타      계     기준년월   대륙  관광비율(%)
# 46  우크라이나  387  26   0      3   1609   2025  2019-01   유럽     19.1
# 50   불가리아  118   5   0      3    527    653  2019-01   유럽     18.1
# 12   스리랑카  180  45   6      9    826   1066  2019-01  아시아     16.9
# 9     미얀마  805  44  40     20   3890   4799  2019-01  아시아     16.8
# 60     교포    0   0   0      0  26715  26715  2019-01   교포      0.0

# %%
kto_201901_country_newindex.pivot_table(values = '관광비율(%)', 
                                        index = '대륙', 
                                        aggfunc='mean')
# Out:
#          관광비율(%)
# 대륙
# 교포      0.000000
# 기타대륙   71.400000
# 아메리카   68.980000
# 아시아    57.215385
# 아프리카   59.400000
# 오세아니아  70.800000
# 유럽     61.117391

# %%
condition = (kto_201901_country_newindex['국적'] == '중국')
kto_201901_country_newindex[condition]
# Out:
#     국적     관광     상용   공용  유학/연수     기타       계     기준년월   대륙  관광비율(%)
# 17  중국  93545  10013  293  11374  60971  176196  2019-01  아시아     53.1

# %% [markdown]
# ### 기준년 월 별로 전체 외국인 관광객 대비 국적별 관광객 비율
# - 1. 전체 관광객 확인

# %%
tourlist_sum = sum(kto_201901_country_newindex['관광'])
tourlist_sum
# Out:
# 546749

# %% [markdown]
# - 2. 나라별 외국인 조사 => coulm명 ['전체비율(%)']

# %%
kto_201901_country_newindex['전체비율(%)'] = round(kto_201901_country_newindex['관광'] / tourlist_sum * 100 , 1)
kto_201901_country_newindex
# Out:
#           국적      관광    상용   공용  유학/연수     기타       계     기준년월     대륙  \
# 0         일본  259846  1791  147    576   5526  267886  2019-01    아시아
# 1         대만   31511    43    5    105    620   32284  2019-01    아시아
# 2         홍콩   13404    39    0     22    841   14306  2019-01    아시아
# 3        마카오     385     1    0      3      2     391  2019-01    아시아
# 4         태국   11562    50   39     50   4524   16225  2019-01    아시아
# ..       ...     ...   ...  ...    ...    ...     ...      ...    ...
# 56  남아프리카공화국     407    24    4      7    459     901  2019-01  오세아니아
# 57   아프리카 기타     988   567   57     91    380    2083  2019-01   아프리카
# 58      기타대륙      10     3    0      0      1      14  2019-01   아프리카
# 59      국적미상      10     3    0      0      1      14  2019-01   기타대륙
# 60        교포       0     0    0      0  26715   26715  2019-01     교포
#
#     관광비율(%)  전체비율(%)
# 0      97.0     47.5
# 1      97.6      5.8
# 2      93.7      2.5
# 3      98.5      0.1
# ...

# %% [markdown]
# - 3. 내림 차순으로 전환

# %%
kto_201901_country_newindex.sort_values(by='전체비율(%)', ascending=False).head()
# Out:
#     국적      관광     상용    공용  유학/연수     기타       계     기준년월   대륙  관광비율(%)  \
# 0   일본  259846   1791   147    576   5526  267886  2019-01  아시아     97.0
# 17  중국   93545  10013   293  11374  60971  176196  2019-01  아시아     53.1
# 25  미국   40747   1119  1283    125  13030   56304  2019-01  아시아     72.4
# 1   대만   31511     43     5    105    620   32284  2019-01  아시아     97.6
# 2   홍콩   13404     39     0     22    841   14306  2019-01  아시아     93.7
#
#     전체비율(%)
# 0      47.5
# 17     17.1
# 25      7.5
# 1       5.8
# 2       2.5

# %% [markdown]
# ## 데이터 전처리 과정 함수로 만들기

# %%
def create_kto_date (yy,mm):
    # 1. 불러올 엑셀 데이터 경로 지정 =>  파일명 ex) kto_201901
    file_path = './files/kto_{}{}.xlsx'.format(yy,mm)
    # 2. 엑셀 파일 불러오기
    df = pd.read_excel(file_path, header = 1, skipfooter=4, usecols='A:G')
    # 3. 기준 년월 컬럼 추가
    df['기준년월'] = '{}-{}'.format(yy,mm)
    # 4. 국적 칼럼에서 대륙 제거하고 국가만 남기기
    ignore_list = ['아시아주', '미주', '구주', '대양주', '아프리카주', '기타대륙', '교포소계']
    condition = (df['국적'].isin(ignore_list)==False) # 대륙 미포함 조건 
    df_country  = df[condition].reset_index(drop=True)
    
    # 5. 대륙 컬럼 추가
    continents = ['아시아'] * 25 + ['아메리카'] * 5 + ['유럽'] * 23 + ['대양주'] * 3 + ['아프리카'] * 2 + ['기타대륙'] + ['교포']
    df_country['대륙'] = continents
    
    # 6. 국가별 '관광비율(%) 칼럼추가'
    df_country['관광객비육(%)'] = round(df_country.관광 / df_country.계 * 100 , 1)
    
    # 7. '전체비율(%)' 칼럼 추가
    tourlist_sum = sum(df_country['관광'])
    df_country['전체비율(%)'] = round(df_country['관광'] / tourlist_sum * 100 , 1)
    
    # 8. 출력
    return(df_country)

# %%
kto_test = create_kto_date(2018,12)
kto_test
# Out:
#           국적      관광    상용    공용  유학/연수     기타       계     기준년월    대륙  \
# 0         일본  252461  1698   161    608   3593  258521  2018-12   아시아
# 1         대만   85697    71    22    266   1252   87308  2018-12   아시아
# 2         홍콩   58355    41     3    208    939   59546  2018-12   아시아
# 3        마카오    6766     0     1     20     36    6823  2018-12   아시아
# 4         태국   47242    42   302     58   6382   54026  2018-12   아시아
# 5      말레이시아   52698    89     3    114   2761   55665  2018-12   아시아
# 6        필리핀   28222   140   127     54  14107   42650  2018-12   아시아
# 7      인도네시아   21276   185   209    141   4278   26089  2018-12   아시아
# 8       싱가포르   38917   105     2     81   1360   40465  2018-12   아시아
# 9        미얀마    1405     8    21     45   4013    5492  2018-12   아시아
# 10       베트남   17814  1184   352   3953   6541   29844  2018-12   아시아
# 11        인도    3090  2215    26     65   3044    8440  2018-12   아시아
# ...

# %%
for yy in range(2010, 2021 ): 
    for mm in range(1,13) : 
        mm = str(mm).zfill(2)
        yymm = '{}{}'.format(yy,mm)
        print(yymm)
# Out:
# 201001
# 201002
# 201003
# 201004
# 201005
# 201006
# 201007
# 201008
# 201009
# 201010
# 201011
# 201012
# 201101
# 201102
# 201103
# 201104
# 201105
# 201106
# 201107
# 201108
# 201109
# 201110
# 201111
# 201112
# 201201
# 201202
# 201203
# 201204
# 201205
# 201206
# 201207
# 201208
# 201209
# 201210
# 201211
# 201212
# 201301
# 201302
# 201303
# 201304
# 201305
# 201306
# 201307
# 201308
# 201309
# 201310
# 201311
# 201312
# 201401
# 201402
# 201403
# 201404
# 201405
# 201406
# 201407
# 201408
# 201409
# 201410
# 201411
# 201412
# 201501
# 201502
# 201503
# 201504
# 201505
# 201506
# 201507
# 201508
# 201509
# 201510
# 201511
# 201512
# 201601
# 201602
# 201603
# 201604
# 201605
# 201606
# 201607
# 201608
# 201609
# 201610
# 201611
# 201612
# 201701
# 201702
# 201703
# 201704
# 201705
# 201706
# 201707
# 201708
# 201709
# 201710
# 201711
# 201712
# 201801
# 201802
# 201803
# 201804
# 201805
# 201806
# 201807
# 201808
# 201809
# 201810
# 201811
# 201812
# 201901
# 201902
# 201903
# ...

# %%
df = pd.DataFrame()

# %%
for yy in range(2010, 2021) : 
    for mm in range (1, 13) : 
        try : 
            temp = create_kto_date(str(yy),str(mm).zfill(2))
            df = df.append(temp, ignore_index= True)
        except : 
            pass

# %%
df.to_excel('./files/kto_total.xlsx', index = False)

# %%
condition = (df['국적'] == '중국')
df_filter = df[condition]
df_filter.head()
# Out:
#      국적     관광     상용   공용  유학/연수     기타       계     기준년월   대륙  관광객비육(%)  \
# 17   중국  40425  11930   55   2751  36091   91252  2010-01  아시아      44.3
# 77   중국  60590   7907   68  29546  42460  140571  2010-02  아시아      43.1
# 137  중국  50330  13549  174  14924  62480  141457  2010-03  아시아      35.6
# 197  중국  84252  13306  212   2199  47711  147680  2010-04  아시아      57.1
# 257  중국  89056  12325  360   2931  49394  154066  2010-05  아시아      57.8
#
#      전체비율(%)
# 17      10.1
# 77      13.6
# 137      9.2
# 197     15.5
# 257     17.0

# %%
path = './files/[국적별 관광객 데이터]중국.xlsx'
df_filter.to_excel(path, index =False)

# %% [markdown]
# ### 시각화

# %%
import pandas as pd
df = pd.read_excel('./files/kto_total.xlsx')
df.head()
# Out:
#     국적      관광    상용  공용  유학/연수    기타       계     기준년월   대륙  관광객비육(%)  전체비율(%)
# 0   일본  202825  1750  89    549  3971  209184  2010-01  아시아      97.0     50.6
# 1   대만   35788    41  17     37   516   36399  2010-01  아시아      98.3      8.9
# 2   홍콩   13874    55   0     21   595   14545  2010-01  아시아      95.4      3.5
# 3  마카오     554     0   0      0     0     554  2010-01  아시아     100.0      0.1
# 4   태국   13374    39  13     53  4335   17814  2010-01  아시아      75.1      3.3

# %%
import matplotlib.pyplot as plt

# %%
condition = (df['국적'] == '중국')
df_filter = df[condition]
df_filter.head()
# Out:
#      국적     관광     상용   공용  유학/연수     기타       계     기준년월   대륙  관광객비육(%)  \
# 17   중국  40425  11930   55   2751  36091   91252  2010-01  아시아      44.3
# 77   중국  60590   7907   68  29546  42460  140571  2010-02  아시아      43.1
# 137  중국  50330  13549  174  14924  62480  141457  2010-03  아시아      35.6
# 197  중국  84252  13306  212   2199  47711  147680  2010-04  아시아      57.1
# 257  중국  89056  12325  360   2931  49394  154066  2010-05  아시아      57.8
#
#      전체비율(%)
# 17      10.1
# 77      13.6
# 137      9.2
# 197     15.5
# 257     17.0

# %%
plt.plot(df_filter)
